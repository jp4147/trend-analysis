# %%
import pandas as pd
noise = pd.load_pickle('R:\Kevin\Projects\trend-analysis\datasets\noise_0.6_beta0.1.pickle')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\K'
# <>:2: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\kr3164\AppData\Local\Temp\ipykernel_21384\4046082728.py:2: SyntaxWarning: invalid escape sequence '\K'
#   noise = pd.load_pickle('R:\Kevin\Projects\trend-analysis\datasets\noise_0.6_beta0.1.pickle')
# C:\Users\kr3164\AppData\Local\Temp\ipykernel_21384\4046082728.py:2: SyntaxWarning: invalid escape sequence '\K'
#   noise = pd.load_pickle('R:\Kevin\Projects\trend-analysis\datasets\noise_0.6_beta0.1.pickle')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 noise = pd.load_pickle('R:\Kevin\Projects\trend-analysis\datasets\noise_0.6_beta0.1.pickle')
#
# AttributeError: module 'pandas' has no attribute 'load_pickle'
